-- %% [markdown]
-- # Fortbildung Jupither Notebook

-- %% [markdown]
-- ## Wichtig
-- - Notebook wird in einem Cookie gespeichert
-- - Reihenfolge der Auführung ist entscheidend
-- - Ausführung mit SHIFT-ENTER
-- - Datenbanken können mit entsprechenden Kernel

-- %%
%CREATE test.db

-- %%
SELECT COUNT(*) as rowcount FROM players
-- Out:
-- +----------+
-- | rowcount |
-- +----------+
-- | 1        |
-- +----------+

-- %%
CREATE TABLE players (Name STRING, Class STRING, Level INTEGER, Hitpoints INTEGER)

-- %%
INSERT INTO players (Name, Class, Level, Hitpoints) VALUES ("Martin Splitskull", "Warrior", 3, 40)

-- %%
select * from players
-- Out:
-- +-------------------+---------+-------+-----------+
-- | Name              | Class   | Level | Hitpoints |
-- +-------------------+---------+-------+-----------+
-- | Martin Splitskull | Warrior | 3     | 40        |
-- +-------------------+---------+-------+-----------+
